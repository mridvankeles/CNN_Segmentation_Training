# %%
import tensorflow as tf
import tensorflow.keras.layers as tfl
import os
from tqdm import tqdm
import cv2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from PIL import Image
from os.path import splitext

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Loading Data & Data Preprocessing</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;">First using the OS library I'll upload the cityscapes pair images.</p>

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
path='../input/cityscapes-image-pairs'
def images_upload(path):
    images=[]
    for root,subfolders,files in os.walk(path):
        for file in tqdm(files):
            filename=root+os.sep+file
            if filename.endswith('jpg') or filename.endwith('png'):
                images.append(filename)
    return images
images=images_upload(path)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 458995.84it/s]
# 100%|██████████| 2975/2975 [00:00<00:00, 713561.75it/s]
# 100%|██████████| 500/500 [00:00<00:00, 479020.56it/s]
# 100%|██████████| 2975/2975 [00:00<00:00, 680188.30it/s]

# %%
def convert_image_rgb(data):
    imgs=[]
    for i in tqdm(data):
        img = cv2.imread(i,cv2.COLOR_BGR2RGB)
        del i
        imgs.append(img)
    return imgs
img=convert_image_rgb(images)
# Out:
# 100%|██████████| 6950/6950 [01:00<00:00, 114.13it/s]

# %% [markdown]
# <p style="padding: 10px;color:black;font-size:120%;font-family: Times New Roman, Times, serif;">Let us look at one of the images. It can be seen that the image contains both the real image and the mask, so the next task will be to distinguish between them. Randmoly has selected the following image.</p>

# %%
plt.imshow(img[np.random.randint(0,len(img))]);

# %% [markdown]
# <p style="padding: 10px;color:black;font-size:120%;font-family: Times New Roman, Times, serif;">Because the image shape is 512*256, it should be divided into two groups, real images and mask images, at 256 pixels on the x axis.</p>

# %%
def split_input_mask(data):
    inputs=[]
    mask=[]
    for i in data:
        a=i[:,:256]
        inputs.append(a)
        b=i[:,256:]
        mask.append(b)
    return inputs,mask
inputs,mask=split_input_mask(img)

# %%
del images
del img

# %% [markdown]
# <p style="padding: 10px;color:black;font-size:120%;font-family: Times New Roman, Times, serif;">In this section, I'll show a few images of the real images as well as a few images of the mask images after they've been separated.</p>

# %%
def show_images(data):
    plt.figure(figsize=(10,10))
    for i in range(9):
        idx=np.random.randint(0,len(data))
        plt.subplot(3,3,i+1)
        img=data[idx]
        plt.imshow(img)
show_images(inputs)

# %%
show_images(mask)

# %%
def images_compare(inputs,mask):
    idx_new=np.random.randint(0,len(mask))
    fig = plt.figure()
    ax1 = fig.add_subplot(1,2,1)
    ax1.imshow(mask[idx_new])
    ax2 = fig.add_subplot(1,2,2)
    ax2.imshow(inputs[idx_new],cmap='gray')
    plt.show()
images_compare(inputs,mask)

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Labeling using K-means</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;">Although each pixel in these images is labeled, it was still necessary to separate the different colors to labels. K-means will be used to categorize these colored labels into ten different groups. This is a hyperparameter. The next few labeled images will be shown, followed by rescaling of the original image.</p>

# %%
num_items = 1000
color_array = np.random.choice(range(256), 3*num_items).reshape(-1,3)
num_classes = 20
label_model = KMeans(n_clusters = num_classes)
label_model.fit(color_array)
label_class = label_model.predict(mask[10].reshape(-1,3)).reshape(256,256)
fig, axes = plt.subplots(1,3,figsize=(15,5))
axes[0].imshow(inputs[10]);
axes[1].imshow(mask[10]);
axes[2].imshow(label_class);

# %%
def new_labels(mask):
    num_items = 1000
    color_array = np.random.choice(range(256), 3*num_items).reshape(-1,3)
    num_classes = 10
    label_model = KMeans(n_clusters = num_classes)
    label_model.fit(color_array)
    labels=[]
    for i in tqdm(range(len(mask))):
        label_class = label_model.predict(mask[i].reshape(-1,3)).reshape(256,256)
        labels.append(label_class)
    return labels

# %%
labels=new_labels(mask)
idx=np.random.randint(0,len(labels))
classes,freq=np.unique(labels[idx],return_counts=True)
print(f'number of classes :{len(classes)}')
# Out:
# 100%|██████████| 6950/6950 [00:26<00:00, 259.50it/s]
# number of classes :9

# %%
plt.figure(figsize=(10,10))
for i in range(9):
        plt.subplot(3,3,i+1)
        im=labels[i]
        plt.imshow(im)
# plt.imshow(a)

# %%
def rescale(data):
    rescaled=[]
    for i in tqdm(data):
        img=tf.image.convert_image_dtype(i, tf.float32)
        del i
        rescaled.append(img)
    return rescaled

# %%
rescaled_input=rescale(inputs)
# Out:
# 100%|██████████| 6950/6950 [00:05<00:00, 1235.61it/s]

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Buliding the model</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;"> Here I'm using UNet since the position of the object is crucial for this task. The feature map is upsampled to the size of the original input image using a transposed convolution layer that preserves the spatial information. It also includes skip connections, which help to keep information that would otherwise be lost during encoding. This model is kind of mini-VGG. </p>

# %%
def build_model(inputsize=(256,256,3),classes=None):
    inputs = tf.keras.Input(shape=(inputsize))

    conv = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv1')(
        inputs)
    x=tfl.BatchNormalization()(conv)
    x=tfl.LeakyReLU()(x)
    x1 = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv2')(
        x)
    x=tfl.BatchNormalization()(x1)
    x=tfl.LeakyReLU()(x)
    x = tfl.MaxPool2D(pool_size=(2, 2), strides=(2, 2), name='MaxPool1')(x)

    x = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv3')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x2 = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv4')(x)
    x=tfl.BatchNormalization()(x2)
    x=tfl.LeakyReLU()(x)
    x = tfl.MaxPool2D(pool_size=(2, 2), name='MaxPool2')(x)

    x = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv5')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x3 = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv6')(x)
    x=tfl.BatchNormalization()(x3)
    x=tfl.LeakyReLU()(x)
    x = tfl.MaxPool2D(pool_size=(2, 2), strides=(2, 2), name='MaxPool3')(x)

    
    x = tfl.Conv2D(256, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv7')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(256, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv8')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    
    x = tfl.Conv2DTranspose(128, (3, 3), strides=2, padding="same")(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)

    x = tfl.concatenate([x, x3], axis=3)
    
    x = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv9')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv10')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2DTranspose(64, (3, 3), strides=2, padding="same")(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)

    x = tfl.concatenate([x, x2], axis=3)

    x = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv11')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv12')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    
    x = tfl.Conv2DTranspose(32, (3, 3), strides=2, padding="same")(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)

    x = tfl.concatenate([x, x1], axis=3)

    x = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv25')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv26')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    
    outputs = tfl.Conv2D(classes, (1, 1), padding="same", activation='softmax', name='Outputs')(x)
    final_model = tf.keras.Model(inputs=inputs, outputs=outputs)
    final_model.summary()
    return final_model

# %%
mymodel=build_model(classes=10)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 256, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# Conv2 (Conv2D)                  (None, 256, 256, 32) 9248        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 32) 128         Conv2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# MaxPool1 (MaxPooling2D)         (None, 128, 128, 32) 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# Conv3 (Conv2D)                  (None, 128, 128, 64) 18496       MaxPool1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         Conv3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 128, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# Conv4 (Conv2D)                  (None, 128, 128, 64) 36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         Conv4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 128, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# MaxPool2 (MaxPooling2D)         (None, 64, 64, 64)   0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# Conv5 (Conv2D)                  (None, 64, 64, 128)  73856       MaxPool2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         Conv5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# Conv6 (Conv2D)                  (None, 64, 64, 128)  147584      leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 128)  512         Conv6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# MaxPool3 (MaxPooling2D)         (None, 32, 32, 128)  0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# Conv7 (Conv2D)                  (None, 32, 32, 256)  295168      MaxPool3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 256)  1024        Conv7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# Conv8 (Conv2D)                  (None, 32, 32, 256)  590080      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 256)  1024        Conv8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 128)  295040      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 128)  512         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 256)  0           leaky_re_lu_8[0][0]
#                                                                  Conv6[0][0]
# __________________________________________________________________________________________________
# Conv9 (Conv2D)                  (None, 64, 64, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 128)  512         Conv9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# Conv10 (Conv2D)                 (None, 64, 64, 128)  147584      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 128)  512         Conv10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 64, 64, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 64) 73792       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 64) 256         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 128, 128, 64) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 128 0           leaky_re_lu_11[0][0]
#                                                                  Conv4[0][0]
# __________________________________________________________________________________________________
# Conv11 (Conv2D)                 (None, 128, 128, 64) 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 64) 256         Conv11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 128, 128, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# Conv12 (Conv2D)                 (None, 128, 128, 64) 36928       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 64) 256         Conv12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 128, 128, 64) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 32) 18464       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 256, 256, 32) 128         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 64) 0           leaky_re_lu_14[0][0]
#                                                                  Conv2[0][0]
# __________________________________________________________________________________________________
# Conv25 (Conv2D)                 (None, 256, 256, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 256, 256, 32) 128         Conv25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# Conv26 (Conv2D)                 (None, 256, 256, 32) 9248        leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 32) 128         Conv26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# Outputs (Conv2D)                (None, 256, 256, 10) 330         leaky_re_lu_16[0][0]
# ==================================================================================================
# Total params: 2,147,466
# Trainable params: 2,144,202
# Non-trainable params: 3,264
# __________________________________________________________________________________________________

# %%
img_file = './model_arch.png'

tf.keras.utils.plot_model(mymodel, to_file=img_file, show_shapes=True, show_layer_names=True)

# %%
del inputs

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Training the model</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;"> The data is divided into train and test segments, with each segment accounting for 80% and 20% of the total. To prevent RAM memory from crashing, I'm using 1300 images. Because the model's output employs 'softmax' activation layer, the loss function is sparse categorical crossentropy. Next, I'm going to use argmax to return the index with the highest value, and then I'm going to make some predictions for the test.</p>

# %%
def split_data(x,y,test_size=0.2):
    x1=np.array(x)
    del x
    y1=np.array(y)
    del y
    x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size=test_size)
    return  x_train, x_test, y_train, y_test

# %%
 x_train, x_test, y_train, y_test=split_data(rescaled_input[:1300],labels[:1300],test_size=0.2)

# %%
def callbacks(patience=5):
    checkpoint = tf.keras.callbacks.ModelCheckpoint('seg_model.h5', monitor='loss', verbose=1, save_best_only=True, save_weights_only=True)
    early=tf.keras.callbacks.EarlyStopping(monitor='loss',patience=patience)
    callbacks_list=[checkpoint, early]
    return callbacks_list

# %%
mymodel.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),loss=tf.keras.losses.sparse_categorical_crossentropy,metrics=['acc'])
hist=mymodel.fit(x_train,y_train,batch_size=16,epochs=200,callbacks=callbacks())
# Out:
# Epoch 1/200
# 65/65 [==============================] - 20s 175ms/step - loss: 1.1445 - acc: 0.6329
#
# Epoch 00001: loss improved from inf to 1.14451, saving model to seg_model.h5
# Epoch 2/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.8519 - acc: 0.7205
#
# Epoch 00002: loss improved from 1.14451 to 0.85192, saving model to seg_model.h5
# Epoch 3/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.7759 - acc: 0.7474
#
# Epoch 00003: loss improved from 0.85192 to 0.77590, saving model to seg_model.h5
# Epoch 4/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.7351 - acc: 0.7594
#
# Epoch 00004: loss improved from 0.77590 to 0.73510, saving model to seg_model.h5
# Epoch 5/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.7123 - acc: 0.7653
#
# Epoch 00005: loss improved from 0.73510 to 0.71234, saving model to seg_model.h5
# Epoch 6/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.6749 - acc: 0.7802
#
# Epoch 00006: loss improved from 0.71234 to 0.67486, saving model to seg_model.h5
# Epoch 7/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.6542 - acc: 0.7859
#
# Epoch 00007: loss improved from 0.67486 to 0.65415, saving model to seg_model.h5
# Epoch 8/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.6301 - acc: 0.7957
#
# Epoch 00008: loss improved from 0.65415 to 0.63006, saving model to seg_model.h5
# Epoch 9/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.6176 - acc: 0.8000
#
# Epoch 00009: loss improved from 0.63006 to 0.61764, saving model to seg_model.h5
# Epoch 10/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5990 - acc: 0.8068
#
# Epoch 00010: loss improved from 0.61764 to 0.59905, saving model to seg_model.h5
# Epoch 11/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5886 - acc: 0.8098
#
# Epoch 00011: loss improved from 0.59905 to 0.58859, saving model to seg_model.h5
# Epoch 12/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5838 - acc: 0.8121
#
# Epoch 00012: loss improved from 0.58859 to 0.58376, saving model to seg_model.h5
# Epoch 13/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5690 - acc: 0.8168
#
# Epoch 00013: loss improved from 0.58376 to 0.56901, saving model to seg_model.h5
# Epoch 14/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5675 - acc: 0.8159
#
# Epoch 00014: loss improved from 0.56901 to 0.56751, saving model to seg_model.h5
# Epoch 15/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5554 - acc: 0.8206
#
# Epoch 00015: loss improved from 0.56751 to 0.55540, saving model to seg_model.h5
# Epoch 16/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5412 - acc: 0.8257
#
# Epoch 00016: loss improved from 0.55540 to 0.54116, saving model to seg_model.h5
# Epoch 17/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5436 - acc: 0.8245
#
# Epoch 00017: loss did not improve from 0.54116
# Epoch 18/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5349 - acc: 0.8273
#
# Epoch 00018: loss improved from 0.54116 to 0.53493, saving model to seg_model.h5
# Epoch 19/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5268 - acc: 0.8295
#
# Epoch 00019: loss improved from 0.53493 to 0.52678, saving model to seg_model.h5
# Epoch 20/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5108 - acc: 0.8344
#
# Epoch 00020: loss improved from 0.52678 to 0.51081, saving model to seg_model.h5
# Epoch 21/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5109 - acc: 0.8350
#
# Epoch 00021: loss did not improve from 0.51081
# Epoch 22/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.5202 - acc: 0.8310
#
# Epoch 00022: loss did not improve from 0.51081
# Epoch 23/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5048 - acc: 0.8372
#
# Epoch 00023: loss improved from 0.51081 to 0.50485, saving model to seg_model.h5
# Epoch 24/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.5085 - acc: 0.8350
#
# Epoch 00024: loss did not improve from 0.50485
# Epoch 25/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4982 - acc: 0.8379
#
# Epoch 00025: loss improved from 0.50485 to 0.49824, saving model to seg_model.h5
# Epoch 26/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4878 - acc: 0.8414
#
# Epoch 00026: loss improved from 0.49824 to 0.48783, saving model to seg_model.h5
# Epoch 27/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4861 - acc: 0.8411
#
# Epoch 00027: loss improved from 0.48783 to 0.48613, saving model to seg_model.h5
# Epoch 28/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.4855 - acc: 0.8424
#
# Epoch 00028: loss improved from 0.48613 to 0.48553, saving model to seg_model.h5
# Epoch 29/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4820 - acc: 0.8426
#
# Epoch 00029: loss improved from 0.48553 to 0.48204, saving model to seg_model.h5
# Epoch 30/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.4728 - acc: 0.8455
#
# Epoch 00030: loss improved from 0.48204 to 0.47283, saving model to seg_model.h5
# Epoch 31/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.4692 - acc: 0.8465
#
# Epoch 00031: loss improved from 0.47283 to 0.46917, saving model to seg_model.h5
# Epoch 32/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4626 - acc: 0.8480
#
# Epoch 00032: loss improved from 0.46917 to 0.46258, saving model to seg_model.h5
# Epoch 33/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4612 - acc: 0.8494
#
# Epoch 00033: loss improved from 0.46258 to 0.46121, saving model to seg_model.h5
# Epoch 34/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4562 - acc: 0.8501
#
# Epoch 00034: loss improved from 0.46121 to 0.45617, saving model to seg_model.h5
# Epoch 35/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4524 - acc: 0.8523
#
# Epoch 00035: loss improved from 0.45617 to 0.45244, saving model to seg_model.h5
# Epoch 36/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.4495 - acc: 0.8521
#
# Epoch 00036: loss improved from 0.45244 to 0.44955, saving model to seg_model.h5
# Epoch 37/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4517 - acc: 0.8515
#
# Epoch 00037: loss did not improve from 0.44955
# Epoch 38/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4414 - acc: 0.8548
#
# Epoch 00038: loss improved from 0.44955 to 0.44139, saving model to seg_model.h5
# Epoch 39/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4419 - acc: 0.8547
#
# Epoch 00039: loss did not improve from 0.44139
# Epoch 40/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4360 - acc: 0.8563
#
# Epoch 00040: loss improved from 0.44139 to 0.43601, saving model to seg_model.h5
# Epoch 41/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4326 - acc: 0.8572
#
# Epoch 00041: loss improved from 0.43601 to 0.43262, saving model to seg_model.h5
# Epoch 42/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4261 - acc: 0.8587
#
# Epoch 00042: loss improved from 0.43262 to 0.42613, saving model to seg_model.h5
# Epoch 43/200
# 65/65 [==============================] - 12s 177ms/step - loss: 0.4251 - acc: 0.8598
#
# Epoch 00043: loss improved from 0.42613 to 0.42512, saving model to seg_model.h5
# Epoch 44/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4241 - acc: 0.8592
#
# Epoch 00044: loss improved from 0.42512 to 0.42408, saving model to seg_model.h5
# Epoch 45/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4165 - acc: 0.8620
#
# Epoch 00045: loss improved from 0.42408 to 0.41646, saving model to seg_model.h5
# Epoch 46/200
# 65/65 [==============================] - 11s 177ms/step - loss: 0.4124 - acc: 0.8625
#
# Epoch 00046: loss improved from 0.41646 to 0.41235, saving model to seg_model.h5
# Epoch 47/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4059 - acc: 0.8652
#
# Epoch 00047: loss improved from 0.41235 to 0.40594, saving model to seg_model.h5
# Epoch 48/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4071 - acc: 0.8649
#
# Epoch 00048: loss did not improve from 0.40594
# Epoch 49/200
# 65/65 [==============================] - 11s 177ms/step - loss: 0.4032 - acc: 0.8655
#
# Epoch 00049: loss improved from 0.40594 to 0.40321, saving model to seg_model.h5
# Epoch 50/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3916 - acc: 0.8693
#
# Epoch 00050: loss improved from 0.40321 to 0.39165, saving model to seg_model.h5
# Epoch 51/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3900 - acc: 0.8697
#
# Epoch 00051: loss improved from 0.39165 to 0.39003, saving model to seg_model.h5
# Epoch 52/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3897 - acc: 0.8694
#
# Epoch 00052: loss improved from 0.39003 to 0.38970, saving model to seg_model.h5
# Epoch 53/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3928 - acc: 0.8685
#
# Epoch 00053: loss did not improve from 0.38970
# Epoch 54/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3857 - acc: 0.8710
#
# Epoch 00054: loss improved from 0.38970 to 0.38574, saving model to seg_model.h5
# Epoch 55/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3804 - acc: 0.8724
#
# Epoch 00055: loss improved from 0.38574 to 0.38044, saving model to seg_model.h5
# Epoch 56/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3801 - acc: 0.8721
#
# Epoch 00056: loss improved from 0.38044 to 0.38008, saving model to seg_model.h5
# Epoch 57/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3709 - acc: 0.8753
#
# Epoch 00057: loss improved from 0.38008 to 0.37094, saving model to seg_model.h5
# Epoch 58/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3700 - acc: 0.8754
#
# Epoch 00058: loss improved from 0.37094 to 0.36995, saving model to seg_model.h5
# Epoch 59/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3679 - acc: 0.8757
#
# Epoch 00059: loss improved from 0.36995 to 0.36793, saving model to seg_model.h5
# Epoch 60/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3732 - acc: 0.8742
#
# Epoch 00060: loss did not improve from 0.36793
# Epoch 61/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3624 - acc: 0.8780
#
# Epoch 00061: loss improved from 0.36793 to 0.36236, saving model to seg_model.h5
# Epoch 62/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3651 - acc: 0.8774
#
# Epoch 00062: loss did not improve from 0.36236
# Epoch 63/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3650 - acc: 0.8769
#
# Epoch 00063: loss did not improve from 0.36236
# Epoch 64/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.3569 - acc: 0.8799
#
# Epoch 00064: loss improved from 0.36236 to 0.35687, saving model to seg_model.h5
# Epoch 65/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3488 - acc: 0.8820
#
# Epoch 00065: loss improved from 0.35687 to 0.34884, saving model to seg_model.h5
# Epoch 66/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3449 - acc: 0.8839
#
# Epoch 00066: loss improved from 0.34884 to 0.34495, saving model to seg_model.h5
# Epoch 67/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.3396 - acc: 0.8852
#
# Epoch 00067: loss improved from 0.34495 to 0.33964, saving model to seg_model.h5
# Epoch 68/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3383 - acc: 0.8861
#
# Epoch 00068: loss improved from 0.33964 to 0.33833, saving model to seg_model.h5
# Epoch 69/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3397 - acc: 0.8851
#
# Epoch 00069: loss did not improve from 0.33833
# Epoch 70/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.3289 - acc: 0.8884
#
# Epoch 00070: loss improved from 0.33833 to 0.32885, saving model to seg_model.h5
# Epoch 71/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3328 - acc: 0.8875
#
# Epoch 00071: loss did not improve from 0.32885
# Epoch 72/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3287 - acc: 0.8887
#
# Epoch 00072: loss improved from 0.32885 to 0.32874, saving model to seg_model.h5
# Epoch 73/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.3240 - acc: 0.8905
#
# Epoch 00073: loss improved from 0.32874 to 0.32401, saving model to seg_model.h5
# Epoch 74/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3165 - acc: 0.8930
#
# Epoch 00074: loss improved from 0.32401 to 0.31650, saving model to seg_model.h5
# Epoch 75/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3143 - acc: 0.8933
#
# Epoch 00075: loss improved from 0.31650 to 0.31435, saving model to seg_model.h5
# Epoch 76/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.3209 - acc: 0.8915
#
# Epoch 00076: loss did not improve from 0.31435
# Epoch 77/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3053 - acc: 0.8965
#
# Epoch 00077: loss improved from 0.31435 to 0.30526, saving model to seg_model.h5
# Epoch 78/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3102 - acc: 0.8946
#
# Epoch 00078: loss did not improve from 0.30526
# Epoch 79/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3027 - acc: 0.8978
#
# Epoch 00079: loss improved from 0.30526 to 0.30268, saving model to seg_model.h5
# Epoch 80/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2916 - acc: 0.9011
#
# Epoch 00080: loss improved from 0.30268 to 0.29156, saving model to seg_model.h5
# Epoch 81/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2898 - acc: 0.9021
#
# Epoch 00081: loss improved from 0.29156 to 0.28979, saving model to seg_model.h5
# Epoch 82/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2898 - acc: 0.9018
#
# Epoch 00082: loss improved from 0.28979 to 0.28979, saving model to seg_model.h5
# Epoch 83/200
# 65/65 [==============================] - 11s 177ms/step - loss: 0.2910 - acc: 0.9011
#
# Epoch 00083: loss did not improve from 0.28979
# Epoch 84/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2874 - acc: 0.9023
#
# Epoch 00084: loss improved from 0.28979 to 0.28737, saving model to seg_model.h5
# Epoch 85/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2787 - acc: 0.9055
#
# Epoch 00085: loss improved from 0.28737 to 0.27866, saving model to seg_model.h5
# Epoch 86/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2819 - acc: 0.9045
#
# Epoch 00086: loss did not improve from 0.27866
# Epoch 87/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2711 - acc: 0.9079
#
# Epoch 00087: loss improved from 0.27866 to 0.27111, saving model to seg_model.h5
# Epoch 88/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2633 - acc: 0.9108
#
# Epoch 00088: loss improved from 0.27111 to 0.26334, saving model to seg_model.h5
# Epoch 89/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2676 - acc: 0.9091
#
# Epoch 00089: loss did not improve from 0.26334
# Epoch 90/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2690 - acc: 0.9087
#
# Epoch 00090: loss did not improve from 0.26334
# Epoch 91/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2631 - acc: 0.9106
#
# Epoch 00091: loss improved from 0.26334 to 0.26315, saving model to seg_model.h5
# Epoch 92/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2703 - acc: 0.9080
#
# Epoch 00092: loss did not improve from 0.26315
# Epoch 93/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2643 - acc: 0.9102
#
# Epoch 00093: loss did not improve from 0.26315
# Epoch 94/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2494 - acc: 0.9152
#
# Epoch 00094: loss improved from 0.26315 to 0.24941, saving model to seg_model.h5
# Epoch 95/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2541 - acc: 0.9136
#
# Epoch 00095: loss did not improve from 0.24941
# Epoch 96/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2515 - acc: 0.9142
#
# Epoch 00096: loss did not improve from 0.24941
# Epoch 97/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2542 - acc: 0.9135
#
# Epoch 00097: loss did not improve from 0.24941
# Epoch 98/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2490 - acc: 0.9152
#
# Epoch 00098: loss improved from 0.24941 to 0.24901, saving model to seg_model.h5
# Epoch 99/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2411 - acc: 0.9179
#
# Epoch 00099: loss improved from 0.24901 to 0.24106, saving model to seg_model.h5
# Epoch 100/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2331 - acc: 0.9204
#
# Epoch 00100: loss improved from 0.24106 to 0.23315, saving model to seg_model.h5
# Epoch 101/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2740 - acc: 0.9062
#
# Epoch 00101: loss did not improve from 0.23315
# Epoch 102/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2447 - acc: 0.9166
#
# Epoch 00102: loss did not improve from 0.23315
# Epoch 103/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2383 - acc: 0.9186
#
# Epoch 00103: loss did not improve from 0.23315
# Epoch 104/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2314 - acc: 0.9208
#
# Epoch 00104: loss improved from 0.23315 to 0.23138, saving model to seg_model.h5
# Epoch 105/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2311 - acc: 0.9209
#
# Epoch 00105: loss improved from 0.23138 to 0.23112, saving model to seg_model.h5
# Epoch 106/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2332 - acc: 0.9202
#
# Epoch 00106: loss did not improve from 0.23112
# Epoch 107/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2400 - acc: 0.9178
#
# Epoch 00107: loss did not improve from 0.23112
# Epoch 108/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2380 - acc: 0.9186
#
# Epoch 00108: loss did not improve from 0.23112
# Epoch 109/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2244 - acc: 0.9230
#
# Epoch 00109: loss improved from 0.23112 to 0.22445, saving model to seg_model.h5
# Epoch 110/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2193 - acc: 0.9246
#
# Epoch 00110: loss improved from 0.22445 to 0.21929, saving model to seg_model.h5
# Epoch 111/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2152 - acc: 0.9260
#
# Epoch 00111: loss improved from 0.21929 to 0.21515, saving model to seg_model.h5
# Epoch 112/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2256 - acc: 0.9223
#
# Epoch 00112: loss did not improve from 0.21515
# Epoch 113/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2398 - acc: 0.9177
#
# Epoch 00113: loss did not improve from 0.21515
# Epoch 114/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2170 - acc: 0.9253
#
# Epoch 00114: loss did not improve from 0.21515
# Epoch 115/200
# 65/65 [==============================] - 11s 177ms/step - loss: 0.2191 - acc: 0.9246
#
# Epoch 00115: loss did not improve from 0.21515
# Epoch 116/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2126 - acc: 0.9266
#
# Epoch 00116: loss improved from 0.21515 to 0.21261, saving model to seg_model.h5
# Epoch 117/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2271 - acc: 0.9221
#
# Epoch 00117: loss did not improve from 0.21261
# Epoch 118/200
# 65/65 [==============================] - 12s 177ms/step - loss: 0.2504 - acc: 0.9138
#
# Epoch 00118: loss did not improve from 0.21261
# Epoch 119/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2232 - acc: 0.9232
#
# Epoch 00119: loss did not improve from 0.21261
# Epoch 120/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2090 - acc: 0.9280
#
# Epoch 00120: loss improved from 0.21261 to 0.20903, saving model to seg_model.h5
# Epoch 121/200
# 65/65 [==============================] - 11s 177ms/step - loss: 0.2033 - acc: 0.9297
#
# Epoch 00121: loss improved from 0.20903 to 0.20328, saving model to seg_model.h5
# Epoch 122/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2043 - acc: 0.9292
#
# Epoch 00122: loss did not improve from 0.20328
# Epoch 123/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.1986 - acc: 0.9311
#
# Epoch 00123: loss improved from 0.20328 to 0.19855, saving model to seg_model.h5
# Epoch 124/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2037 - acc: 0.9292
#
# Epoch 00124: loss did not improve from 0.19855
# Epoch 125/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2082 - acc: 0.9279
#
# Epoch 00125: loss did not improve from 0.19855
# Epoch 126/200
# 65/65 [==============================] - 11s 174ms/step - loss: 0.2431 - acc: 0.9163
#
# Epoch 00126: loss did not improve from 0.19855
# Epoch 127/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2391 - acc: 0.9177
#
# Epoch 00127: loss did not improve from 0.19855
# Epoch 128/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2063 - acc: 0.9285
#
# Epoch 00128: loss did not improve from 0.19855

# %%
plt.plot(hist.history['loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

# %%
plt.plot(hist.history["acc"])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.show()

# %%
pred=mymodel.predict(x_test)
y_pred=tf.argmax(pred,axis=-1)

# %%
def show_predications(x_test,y_test,y_pred):
    idx=np.random.randint(0,len(y_pred))
    fig, axes = plt.subplots(1,3,figsize=(10,10))
    axes[0].imshow(x_test[idx])
    axes[0].set_title("original")
    axes[1].imshow(y_test[idx])
    axes[1].set_title("mask")
    axes[2].imshow(y_pred[idx])
    axes[2].set_title("predicated")

# %%
for i in range(3):
    show_predications(x_test,y_test,y_pred)

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Conclusions</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;">
# Despite the fact that the results are not amazing, they are not so bad. More layers, as well as augmentations and different class clustering, are required for even better results.</p>
